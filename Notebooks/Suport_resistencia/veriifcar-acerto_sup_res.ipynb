# %%
import pandas as pd

# %%
df = pd.read_csv('eurusd1_candlepatterns_4.csv')
df.sort_values(by = 'Taxa_acerto',ascending=False).head(10)
# Out:
#     Timeframe  pontos  zig_zag_percent  merge_percent  rate_tp  N_trades  \
# 36          1  0.0003              0.1            0.3        1        65
# 42          1  0.0003              0.2            0.3        1        40
# 18          1  0.0003              0.1            0.2        1        74
# 48          1  0.0003              0.3            0.3        1        38
# 0           1  0.0003              0.1            0.1        1        98
# 24          1  0.0003              0.2            0.2        1        52
# 6           1  0.0003              0.2            0.1        1        90
# 30          1  0.0003              0.3            0.2        1        51
# 12          1  0.0003              0.3            0.1        1        61
# 31          1  0.0005              0.3            0.2        1        50
#
#     Taxa_acerto  Pontos_total   Retorno
# 36    83.076923       0.00965  1.322234
# 42    82.500000       0.00580  0.778161
# 18    81.081081       0.01010  1.431710
# ...

# %%
df = pd.read_csv('eurusd1_candlepatterns_8.csv')
df.sort_values(by = 'Taxa_acerto',ascending=False).head(10)
# Out:
#     Timeframe  pontos  zig_zag_percent  merge_percent  rate_tp  N_trades  \
# 14          1  0.0003              0.2            0.3        1        75
# 12          1  0.0003              0.1            0.3        1       112
# 8           1  0.0003              0.2            0.2        1        90
# 2           1  0.0003              0.2            0.1        1       139
# 6           1  0.0003              0.1            0.2        1       133
# 13          1  0.0005              0.1            0.3        1       110
# 16          1  0.0003              0.3            0.3        1        61
# 10          1  0.0003              0.3            0.2        1        84
# 0           1  0.0003              0.1            0.1        1       176
# 4           1  0.0003              0.3            0.1        1        97
#
#     Taxa_acerto  Pontos_total   Retorno
# 14    81.333333       0.01035  1.425443
# 12    79.464286       0.01420  2.051857
# 8     76.666667       0.00990  1.463514
# ...

# %%
df = pd.read_csv('eurusd5_candlepatterns_8.csv')
df.sort_values(by = 'Taxa_acerto',ascending=False).head(10)
# Out:
#     Timeframe  pontos  zig_zag_percent  merge_percent  rate_tp  N_trades  \
# 25          1  0.0005              0.2            0.2        1       148
# 43          1  0.0005              0.2            0.3        1       135
# 36          1  0.0003              0.1            0.3        1       150
# 1           1  0.0005              0.1            0.1        1       190
# 37          1  0.0005              0.1            0.3        1       150
# 13          1  0.0005              0.3            0.1        1       183
# 6           1  0.0003              0.2            0.1        1       179
# 7           1  0.0005              0.2            0.1        1       179
# 31          1  0.0005              0.3            0.2        1       148
# 24          1  0.0003              0.2            0.2        1       148
#
#     Taxa_acerto  Pontos_total   Retorno
# 25    87.162162       0.04760  5.713817
# 43    85.925926       0.04175  5.051586
# 36    84.666667       0.02370  3.315967
# ...

# %%
df = pd.read_csv('eurusd5_engulfing_6.csv')
df.sort_values(by = 'Taxa_acerto',ascending=False).head(10)
# Out:
#     Timeframe  pontos  zig_zag_percent  merge_percent  rate_tp  N_trades  \
# 15          1  0.0005              0.2            0.3        1        93
# 9           1  0.0005              0.2            0.2        1        96
# 12          1  0.0003              0.1            0.3        1        96
# 6           1  0.0003              0.1            0.2        1       103
# 13          1  0.0005              0.1            0.3        1        96
# 1           1  0.0005              0.1            0.1        1       125
# 0           1  0.0003              0.1            0.1        1       125
# 3           1  0.0005              0.2            0.1        1       123
# 8           1  0.0003              0.2            0.2        1        96
# 10          1  0.0003              0.3            0.2        1        94
#
#     Taxa_acerto  Pontos_total   Retorno
# 15    83.870968       0.02685  3.250423
# 9     83.333333       0.02720  3.310560
# 12    83.333333       0.01440  2.062321
# ...
